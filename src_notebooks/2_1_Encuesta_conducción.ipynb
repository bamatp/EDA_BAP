# %% [markdown]
# ## ***Resultados de la encuesta efectuada a 100 participantes sobre aspectos relacionados con la conducción de vehículos***

# %% [markdown]
# #### **Preguntas realizadas**

# %% [markdown]
# 1) Introduce tu edad
#
# 2) ¿Tienes carnet de conducir?
#
# 3) ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?
#
# 4) En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?

# %% [markdown]
# #### **Obtención de los resultados de la encuesta**

# %%
import pandas as pd

# %%
"""En primer lugar, abrimos el archivo csv donde aparecen recopilados los resultados de la encuesta efectuada
https://docs.google.com/spreadsheets/d/1espVWoKwtwFrv8hBeUP1q_k0yeCzYwbzXngXrI0uWNM/edit#gid=998776026"""

resultados_encuesta = pd.read_csv('resultados_encuesta.csv', sep = ',')

"""En segundo lugar, descartamos las dos primeras columnas, ya que aparecía la marca temporal de las respuestas 
y la puntuación obtenida de las mismas, datos que no resultaban relevantes para el análisis."""

resultados_encuesta = resultados_encuesta[resultados_encuesta.columns[2:]]

"""En tercer lugar, descartamos las respuestas de participantes mayores a 34 años, ya que interesa conocer 
únicamente las respuestas de los participantes menores de 34 años."""

filtro_edad = resultados_encuesta['Introduce tu edad'] < '35'
resultados_encuesta = resultados_encuesta[filtro_edad]

"""En cuarto lugar, dividimos los resultados de la encuesta en dos partes: conducción y RRSSS. Para este caso, 
necesitamos únicamente las tres primeras columnas, ya que son las que contienen información relacionada con la conducción."""

accidentes_trafico = resultados_encuesta[resultados_encuesta.columns[1:4]]

# %% [markdown]
# 1) Primer paso

# %%
resultados_encuesta = pd.read_csv('resultados_encuesta.csv', sep = ',')
resultados_encuesta
# Out:
#          Marca temporal  Puntuación Introduce tu edad  \
# 0    15/03/2023 0:05:02         NaN                27
# 1    15/03/2023 0:09:26         NaN                29
# 2    15/03/2023 0:10:04         NaN                26
# 3    15/03/2023 0:10:16         NaN                26
# 4    15/03/2023 0:11:15         NaN                24
# ..                  ...         ...               ...
# 89  15/03/2023 14:13:45         NaN                24
# 90  15/03/2023 16:14:10         NaN                19
# 91  15/03/2023 16:24:33         NaN                30
# 92  15/03/2023 16:55:35         NaN            Miguel
# 93   16/03/2023 7:14:27         NaN                27
#
#    ¿Tienes carnet de conducir?  \
# 0                           Si
# 1                           Si
# 2                           Si
# 3                           No
# 4                           Si
# ..                         ...
# 89                          Si
# 90                          Si
# 91                          Si
# 92                          No
# 93                          Si
#
#    ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                 No
# 92                                                 No
# 93                                                 Sí
#
#    En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?  \
# 0                                             Sanción
# 1     Poner en peligro la seguridad de otras personas
# 2     Poner en peligro la seguridad de otras personas
# 3     Poner en peligro la seguridad de otras personas
# 4                                                 NaN
# ..                                                ...
# 89    Poner en peligro la seguridad de otras personas
# 90    Poner en peligro la seguridad de otras personas
# 91                                                NaN
# 92                                                NaN
# 93    Poner en peligro la seguridad de otras personas
#
#    ¿Alguna vez te has comparado con personas a las que sigues en RRSS?  \
# 0                                          Alguna vez
# 1                                          Alguna vez
# 2                                                  Sí
# 3                                          Alguna vez
# 4                                                  Sí
# ..                                                ...
# 89                                                 Sí
# 90                                                 Sí
# 91                                                 No
# 92                                         Alguna vez
# 93                                                 No
#
#    ¿Te has sentido inferior al hacerlo?  \
# 0                            Alguna vez
# 1                                    No
# 2                                    Sí
# 3                            Alguna vez
# 4                                    Sí
# ..                                  ...
# 89                           Alguna vez
# 90                                   Sí
# 91                                  NaN
# 92                                   No
# 93                                   No
#
#    ¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                             Depende
# 4                                                  Sí
# ..                                                ...
# 89                                            Depende
# 90                                                 Sí
# 91                                                 Sí
# 92                                            Depende
# 93                                                 Sí
#
#    ¿Has estado algun periodo de tiempo sin RRSS para desconectar?  \
# 0                                          Una semana
# 1                                          Una semana
# 2                                       Más de un mes
# 3                                       Más de un mes
# 4                                       Más de un mes
# ..                                                ...
# 89                                         Una semana
# 90                                             Un mes
# 91                                             Un mes
# 92                                         Una semana
# 93                                         Una semana
#
#    En caso afirmativo, ¿crees que te benefició?  \
# 0                           En algunos aspectos
# 1                           En algunos aspectos
# 2                                            Sí
# 3                           En algunos aspectos
# 4                                            Sí
# ..                                          ...
# 89                          En algunos aspectos
# 90                                           Sí
# 91                                           Sí
# 92                          En algunos aspectos
# 93                                           Sí
#
#    ¿Consideras que la gente que te rodea goza de una buena salud mental?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  No
# 3                                Lo aparentan pero no
# 4                                Lo aparentan pero no
# ..                                                ...
# 89                                                 Sí
# 90                               Lo aparentan pero no
# 91                               Lo aparentan pero no
# 92                                                 No
# 93                               Lo aparentan pero no
#
#                 Indica el por qué crees que no tienen  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Veo a mucha gente rota. Es una pauta general. ...
# 4                                                 NaN
# ..                                                ...
# 89                                                NaN
# 90                                       Inseguridad
# 91  Falta de autoestima por comparativa ante vidas...
# 92                                           Sociedad
# 93  Porque las RRSS (Tiktok e Instagram sobretodo)...
#
#    ¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?  \
# 0                                           Psicólogo
# 1                                           Psicólogo
# 2                        Me esperaría a que se pasara
# 3                        Me esperaría a que se pasara
# 4                                           Psicólogo
# ..                                                ...
# 89                                          Psicólogo
# 90                                          Psicólogo
# 91                                          Psicólogo
# 92                                          Psicólogo
# 93                                          Psicólogo
#
#    En caso de que ya acudas a uno, ¿te da vergüenza que lo sepa tu círculo?
# 0                                    Depende de quien
# 1                                                  No
# 2                                                  No
# 3                                    Depende de quien
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                NaN
# 92                                                 No
# 93                                                 No
#
# [94 rows x 15 columns]

# %% [markdown]
# 2) Segundo paso

# %%
resultados_encuesta = resultados_encuesta[resultados_encuesta.columns[2:]]
resultados_encuesta
# Out:
#    Introduce tu edad ¿Tienes carnet de conducir?  \
# 0                 27                          Si
# 1                 29                          Si
# 2                 26                          Si
# 3                 26                          No
# 4                 24                          Si
# ..               ...                         ...
# 89                24                          Si
# 90                19                          Si
# 91                30                          Si
# 92            Miguel                          No
# 93                27                          Si
#
#    ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                 No
# 92                                                 No
# 93                                                 Sí
#
#    En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?  \
# 0                                             Sanción
# 1     Poner en peligro la seguridad de otras personas
# 2     Poner en peligro la seguridad de otras personas
# 3     Poner en peligro la seguridad de otras personas
# 4                                                 NaN
# ..                                                ...
# 89    Poner en peligro la seguridad de otras personas
# 90    Poner en peligro la seguridad de otras personas
# 91                                                NaN
# 92                                                NaN
# 93    Poner en peligro la seguridad de otras personas
#
#    ¿Alguna vez te has comparado con personas a las que sigues en RRSS?  \
# 0                                          Alguna vez
# 1                                          Alguna vez
# 2                                                  Sí
# 3                                          Alguna vez
# 4                                                  Sí
# ..                                                ...
# 89                                                 Sí
# 90                                                 Sí
# 91                                                 No
# 92                                         Alguna vez
# 93                                                 No
#
#    ¿Te has sentido inferior al hacerlo?  \
# 0                            Alguna vez
# 1                                    No
# 2                                    Sí
# 3                            Alguna vez
# 4                                    Sí
# ..                                  ...
# 89                           Alguna vez
# 90                                   Sí
# 91                                  NaN
# 92                                   No
# 93                                   No
#
#    ¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                             Depende
# 4                                                  Sí
# ..                                                ...
# 89                                            Depende
# 90                                                 Sí
# 91                                                 Sí
# 92                                            Depende
# 93                                                 Sí
#
#    ¿Has estado algun periodo de tiempo sin RRSS para desconectar?  \
# 0                                          Una semana
# 1                                          Una semana
# 2                                       Más de un mes
# 3                                       Más de un mes
# 4                                       Más de un mes
# ..                                                ...
# 89                                         Una semana
# 90                                             Un mes
# 91                                             Un mes
# 92                                         Una semana
# 93                                         Una semana
#
#    En caso afirmativo, ¿crees que te benefició?  \
# 0                           En algunos aspectos
# 1                           En algunos aspectos
# 2                                            Sí
# 3                           En algunos aspectos
# 4                                            Sí
# ..                                          ...
# 89                          En algunos aspectos
# 90                                           Sí
# 91                                           Sí
# 92                          En algunos aspectos
# 93                                           Sí
#
#    ¿Consideras que la gente que te rodea goza de una buena salud mental?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  No
# 3                                Lo aparentan pero no
# 4                                Lo aparentan pero no
# ..                                                ...
# 89                                                 Sí
# 90                               Lo aparentan pero no
# 91                               Lo aparentan pero no
# 92                                                 No
# 93                               Lo aparentan pero no
#
#                 Indica el por qué crees que no tienen  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Veo a mucha gente rota. Es una pauta general. ...
# 4                                                 NaN
# ..                                                ...
# 89                                                NaN
# 90                                       Inseguridad
# 91  Falta de autoestima por comparativa ante vidas...
# 92                                           Sociedad
# 93  Porque las RRSS (Tiktok e Instagram sobretodo)...
#
#    ¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?  \
# 0                                           Psicólogo
# 1                                           Psicólogo
# 2                        Me esperaría a que se pasara
# 3                        Me esperaría a que se pasara
# 4                                           Psicólogo
# ..                                                ...
# 89                                          Psicólogo
# 90                                          Psicólogo
# 91                                          Psicólogo
# 92                                          Psicólogo
# 93                                          Psicólogo
#
#    En caso de que ya acudas a uno, ¿te da vergüenza que lo sepa tu círculo?
# 0                                    Depende de quien
# 1                                                  No
# 2                                                  No
# 3                                    Depende de quien
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                NaN
# 92                                                 No
# 93                                                 No
#
# [94 rows x 13 columns]

# %% [markdown]
# 3) Tercer paso

# %%
filtro_edad = resultados_encuesta['Introduce tu edad'] < '35'
resultados_encuesta = resultados_encuesta[filtro_edad]
resultados_encuesta
# Out:
#    Introduce tu edad ¿Tienes carnet de conducir?  \
# 0                 27                          Si
# 1                 29                          Si
# 2                 26                          Si
# 3                 26                          No
# 4                 24                          Si
# ..               ...                         ...
# 88                17                          No
# 89                24                          Si
# 90                19                          Si
# 91                30                          Si
# 93                27                          Si
#
#    ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  No
# ..                                                ...
# 88                                                 No
# 89                                                 No
# 90                                                 No
# 91                                                 No
# 93                                                 Sí
#
#    En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?  \
# 0                                             Sanción
# 1     Poner en peligro la seguridad de otras personas
# 2     Poner en peligro la seguridad de otras personas
# 3     Poner en peligro la seguridad de otras personas
# 4                                                 NaN
# ..                                                ...
# 88                                                NaN
# 89    Poner en peligro la seguridad de otras personas
# 90    Poner en peligro la seguridad de otras personas
# 91                                                NaN
# 93    Poner en peligro la seguridad de otras personas
#
#    ¿Alguna vez te has comparado con personas a las que sigues en RRSS?  \
# 0                                          Alguna vez
# 1                                          Alguna vez
# 2                                                  Sí
# 3                                          Alguna vez
# 4                                                  Sí
# ..                                                ...
# 88                                         Alguna vez
# 89                                                 Sí
# 90                                                 Sí
# 91                                                 No
# 93                                                 No
#
#    ¿Te has sentido inferior al hacerlo?  \
# 0                            Alguna vez
# 1                                    No
# 2                                    Sí
# 3                            Alguna vez
# 4                                    Sí
# ..                                  ...
# 88                           Alguna vez
# 89                           Alguna vez
# 90                                   Sí
# 91                                  NaN
# 93                                   No
#
#    ¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                             Depende
# 4                                                  Sí
# ..                                                ...
# 88                                            Depende
# 89                                            Depende
# 90                                                 Sí
# 91                                                 Sí
# 93                                                 Sí
#
#    ¿Has estado algun periodo de tiempo sin RRSS para desconectar?  \
# 0                                          Una semana
# 1                                          Una semana
# 2                                       Más de un mes
# 3                                       Más de un mes
# 4                                       Más de un mes
# ..                                                ...
# 88                                         Una semana
# 89                                         Una semana
# 90                                             Un mes
# 91                                             Un mes
# 93                                         Una semana
#
#    En caso afirmativo, ¿crees que te benefició?  \
# 0                           En algunos aspectos
# 1                           En algunos aspectos
# 2                                            Sí
# 3                           En algunos aspectos
# 4                                            Sí
# ..                                          ...
# 88                          En algunos aspectos
# 89                          En algunos aspectos
# 90                                           Sí
# 91                                           Sí
# 93                                           Sí
#
#    ¿Consideras que la gente que te rodea goza de una buena salud mental?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  No
# 3                                Lo aparentan pero no
# 4                                Lo aparentan pero no
# ..                                                ...
# 88                               Lo aparentan pero no
# 89                                                 Sí
# 90                               Lo aparentan pero no
# 91                               Lo aparentan pero no
# 93                               Lo aparentan pero no
#
#                 Indica el por qué crees que no tienen  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Veo a mucha gente rota. Es una pauta general. ...
# 4                                                 NaN
# ..                                                ...
# 88    no concuerda lo que dicen con lo que demuestran
# 89                                                NaN
# 90                                       Inseguridad
# 91  Falta de autoestima por comparativa ante vidas...
# 93  Porque las RRSS (Tiktok e Instagram sobretodo)...
#
#    ¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?  \
# 0                                           Psicólogo
# 1                                           Psicólogo
# 2                        Me esperaría a que se pasara
# 3                        Me esperaría a que se pasara
# 4                                           Psicólogo
# ..                                                ...
# 88                                          Psicólogo
# 89                                          Psicólogo
# 90                                          Psicólogo
# 91                                          Psicólogo
# 93                                          Psicólogo
#
#    En caso de que ya acudas a uno, ¿te da vergüenza que lo sepa tu círculo?
# 0                                    Depende de quien
# 1                                                  No
# 2                                                  No
# 3                                    Depende de quien
# 4                                                  No
# ..                                                ...
# 88                                                 No
# 89                                                 No
# 90                                                 No
# 91                                                NaN
# 93                                                 No
#
# [87 rows x 13 columns]

# %% [markdown]
# 4) Cuarto paso

# %%
accidentes_trafico = resultados_encuesta[resultados_encuesta.columns[1:4]]
accidentes_trafico
# Out:
#    ¿Tienes carnet de conducir?  \
# 0                           Si
# 1                           Si
# 2                           Si
# 3                           No
# 4                           Si
# ..                         ...
# 88                          No
# 89                          Si
# 90                          Si
# 91                          Si
# 93                          Si
#
#    ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  No
# ..                                                ...
# 88                                                 No
# 89                                                 No
# 90                                                 No
# 91                                                 No
# 93                                                 Sí
#
#    En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?
# 0                                             Sanción
# 1     Poner en peligro la seguridad de otras personas
# 2     Poner en peligro la seguridad de otras personas
# 3     Poner en peligro la seguridad de otras personas
# 4                                                 NaN
# ..                                                ...
# 88                                                NaN
# 89    Poner en peligro la seguridad de otras personas
# 90    Poner en peligro la seguridad de otras personas
# 91                                                NaN
# 93    Poner en peligro la seguridad de otras personas
#
# [87 rows x 3 columns]

# %% [markdown]
# #### **Análisis de los datos de los resultados de la encuesta**
#
# ##### - Tras descartar los participantes de las edades que se han mencionado anteriormente, nos ha quedado una muestra de 87 personas.

# %%
"""En primer lugar, vamos a descartar a aquellos participantes que no tienen carnet de conducir, 
ya que las respuestas que nos interesan para el estudio son de personas que conducen."""

filtro_conductores = accidentes_trafico['¿Tienes carnet de conducir?'] == 'Si'
accidentes_trafico = accidentes_trafico[filtro_conductores]

"""En segundo lugar, vamos a conocer el porcentaje de participantes que afirman haber hecho uso de un vehículo 
bajo la influencia de alcohol o estupefacientes."""

conduccion_temeraria = accidentes_trafico['¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?'] == 'Sí'
conduccion_temeraria = accidentes_trafico[conduccion_temeraria]

"""En tercer lugar, vamos a conocer el porcentaje de participantes que niegan haber hecho uso de un vehículo bajo 
la influencia de alcohol o estupefacientes."""

conduccion_responsable = accidentes_trafico['¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?'] == 'No'
conduccion_responsable = accidentes_trafico[conduccion_responsable]

"""En cuarto lugar, vamos a conocer el porcentaje de las causas que más reparo da a los participantes que han conducido un vehículo 
de manera temeraria."""

multa2 = conduccion_temeraria['En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?'] == "Multa"
multa2 = conduccion_temeraria[multa2]

sanción2 = conduccion_temeraria['En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?'] == "Sanción"
sanción2 = conduccion_temeraria[sanción2]

seguridad2 = conduccion_temeraria['En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?'] == "Poner en peligro la seguridad de otras personas"
seguridad2 = conduccion_temeraria[seguridad2]

# %% [markdown]
# #### **Comprobaciones realizadas y conclusiones**

# %% [markdown]
# 1) Primer paso

# %%
"""Tras aplicar el filtro de personas que tienen carnet de conducir, la muestra se reduce a un total de 73 participantes."""
accidentes_trafico.shape
# Out:
# (73, 3)

# %% [markdown]
# 2) Segundo paso

# %%
"""De los 73 participantes, el 56,17% afirma haber conducido bajo los efectos de alcohol o estupefacientes."""
conduccion_temeraria.shape

ct = 41/73
ct = ct*100
ct
# Out:
# 56.16438356164384

# %% [markdown]
# 3. Tercer paso

# %%
"""De los 73 participantes, el 43,83% niega haber conducido bajo los efectos de alcohol o estupefacientes."""
conduccion_responsable.shape

cr = 32/73
cr*100
# Out:
# 43.83561643835616

# %% [markdown]
# 4) Cuarto paso

# %%
"""De los 41 participantes que afirman haber conducido de manera temeraria, el 29,27% de ellos opina que lo que más les frena a hacerlo es la multa económica."""
multa2.shape

multa = 12/41
multa*100
# Out:
# 29.268292682926827

# %%
"""De los 41 participantes que afirman haber conducido de manera temeraria, el 10,96% de ellos opina que lo que más les frena a hacerlo es la sanción."""
sanción2.shape

sanción = 8/73
sanción*100
# Out:
# 10.95890410958904

# %%
"""De los 41 participantes que afirman haber conducido de manera temeraria, el 51,22% de ellos opina que lo que más les frena a hacerlo es poner en peligro la seguridad de otras personas."""
seguridad2.shape

seguridad= 21/41
seguridad*100
# Out:
# 51.21951219512195

# %% [markdown]
# *Exportación del data frame a excel para utilizarlo en la presentación del proyecto en Power BI*

# %%
resultados_encuesta.to_excel("resultado.xlsx")
