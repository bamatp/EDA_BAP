# %% [markdown]
# ### ***Resultados de la primera encuesta efectuada a 100 participantes sobre aspectos relacionados con la conducción de vehículos***

# %% [markdown]
# - ##### Marzo 2023

# %% [markdown]
# #### **Preguntas realizadas**

# %% [markdown]
# 1) Introduce tu edad
#
# 2) ¿Tienes carnet de conducir?
#
# 3) ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?
#
# 4) En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?

# %% [markdown]
# #### **Obtención de los resultados de la primera encuesta**

# %%
import pandas as pd

# %%
"""En primer lugar, abrimos el archivo csv donde aparecen recopilados los resultados de la encuesta efectuada
https://docs.google.com/spreadsheets/d/1espVWoKwtwFrv8hBeUP1q_k0yeCzYwbzXngXrI0uWNM/edit#gid=998776026"""

resultados_encuesta = pd.read_csv('resultados_encuesta.csv', sep = ',')

"""En segundo lugar, descartamos las dos primeras columnas, ya que aparecía la marca temporal de las respuestas 
y la puntuación obtenida de las mismas, datos que no resultaban relevantes para el análisis."""

resultados_encuesta = resultados_encuesta[resultados_encuesta.columns[2:]]

"""En tercer lugar, descartamos las respuestas de participantes mayores a 34 años, ya que interesa conocer 
únicamente las respuestas de los participantes menores de 34 años."""

filtro_edad = resultados_encuesta['Introduce tu edad'] < '35'
resultados_encuesta = resultados_encuesta[filtro_edad]

"""En cuarto lugar, dividimos los resultados de la encuesta en dos partes: conducción y RRSSS. Para este caso, 
necesitamos únicamente las tres primeras columnas, ya que son las que contienen información relacionada con la conducción."""

accidentes_trafico = resultados_encuesta[resultados_encuesta.columns[1:4]]

# %% [markdown]
# 1) Primer paso

# %%
resultados_encuesta = pd.read_csv('resultados_encuesta.csv', sep = ',')
resultados_encuesta
# Out:
#          Marca temporal  Puntuación Introduce tu edad  \
# 0    15/03/2023 0:05:02         NaN                27
# 1    15/03/2023 0:09:26         NaN                29
# 2    15/03/2023 0:10:04         NaN                26
# 3    15/03/2023 0:10:16         NaN                26
# 4    15/03/2023 0:11:15         NaN                24
# ..                  ...         ...               ...
# 89  15/03/2023 14:13:45         NaN                24
# 90  15/03/2023 16:14:10         NaN                19
# 91  15/03/2023 16:24:33         NaN                30
# 92  15/03/2023 16:55:35         NaN            Miguel
# 93   16/03/2023 7:14:27         NaN                27
#
#    ¿Tienes carnet de conducir?  \
# 0                           Si
# 1                           Si
# 2                           Si
# 3                           No
# 4                           Si
# ..                         ...
# 89                          Si
# 90                          Si
# 91                          Si
# 92                          No
# 93                          Si
#
#    ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                 No
# 92                                                 No
# 93                                                 Sí
#
#    En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?  \
# 0                                             Sanción
# 1     Poner en peligro la seguridad de otras personas
# 2     Poner en peligro la seguridad de otras personas
# 3     Poner en peligro la seguridad de otras personas
# 4                                                 NaN
# ..                                                ...
# 89    Poner en peligro la seguridad de otras personas
# 90    Poner en peligro la seguridad de otras personas
# 91                                                NaN
# 92                                                NaN
# 93    Poner en peligro la seguridad de otras personas
#
#    ¿Alguna vez te has comparado con personas a las que sigues en RRSS?  \
# 0                                          Alguna vez
# 1                                          Alguna vez
# 2                                                  Sí
# 3                                          Alguna vez
# 4                                                  Sí
# ..                                                ...
# 89                                                 Sí
# 90                                                 Sí
# 91                                                 No
# 92                                         Alguna vez
# 93                                                 No
#
#    ¿Te has sentido inferior al hacerlo?  \
# 0                            Alguna vez
# 1                                    No
# 2                                    Sí
# 3                            Alguna vez
# 4                                    Sí
# ..                                  ...
# 89                           Alguna vez
# 90                                   Sí
# 91                                  NaN
# 92                                   No
# 93                                   No
#
#    ¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                             Depende
# 4                                                  Sí
# ..                                                ...
# 89                                            Depende
# 90                                                 Sí
# 91                                                 Sí
# 92                                            Depende
# 93                                                 Sí
#
#    ¿Has estado algun periodo de tiempo sin RRSS para desconectar?  \
# 0                                          Una semana
# 1                                          Una semana
# 2                                       Más de un mes
# 3                                       Más de un mes
# 4                                       Más de un mes
# ..                                                ...
# 89                                         Una semana
# 90                                             Un mes
# 91                                             Un mes
# 92                                         Una semana
# 93                                         Una semana
#
#    En caso afirmativo, ¿crees que te benefició?  \
# 0                           En algunos aspectos
# 1                           En algunos aspectos
# 2                                            Sí
# 3                           En algunos aspectos
# 4                                            Sí
# ..                                          ...
# 89                          En algunos aspectos
# 90                                           Sí
# 91                                           Sí
# 92                          En algunos aspectos
# 93                                           Sí
#
#    ¿Consideras que la gente que te rodea goza de una buena salud mental?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  No
# 3                                Lo aparentan pero no
# 4                                Lo aparentan pero no
# ..                                                ...
# 89                                                 Sí
# 90                               Lo aparentan pero no
# 91                               Lo aparentan pero no
# 92                                                 No
# 93                               Lo aparentan pero no
#
#                 Indica el por qué crees que no tienen  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Veo a mucha gente rota. Es una pauta general. ...
# 4                                                 NaN
# ..                                                ...
# 89                                                NaN
# 90                                       Inseguridad
# 91  Falta de autoestima por comparativa ante vidas...
# 92                                           Sociedad
# 93  Porque las RRSS (Tiktok e Instagram sobretodo)...
#
#    ¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?  \
# 0                                           Psicólogo
# 1                                           Psicólogo
# 2                        Me esperaría a que se pasara
# 3                        Me esperaría a que se pasara
# 4                                           Psicólogo
# ..                                                ...
# 89                                          Psicólogo
# 90                                          Psicólogo
# 91                                          Psicólogo
# 92                                          Psicólogo
# 93                                          Psicólogo
#
#    En caso de que ya acudas a uno, ¿te da vergüenza que lo sepa tu círculo?
# 0                                    Depende de quien
# 1                                                  No
# 2                                                  No
# 3                                    Depende de quien
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                NaN
# 92                                                 No
# 93                                                 No
#
# [94 rows x 15 columns]

# %% [markdown]
# 2) Segundo paso

# %%
resultados_encuesta = resultados_encuesta[resultados_encuesta.columns[2:]]
resultados_encuesta
# Out:
#    Introduce tu edad ¿Tienes carnet de conducir?  \
# 0                 27                          Si
# 1                 29                          Si
# 2                 26                          Si
# 3                 26                          No
# 4                 24                          Si
# ..               ...                         ...
# 89                24                          Si
# 90                19                          Si
# 91                30                          Si
# 92            Miguel                          No
# 93                27                          Si
#
#    ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                 No
# 92                                                 No
# 93                                                 Sí
#
#    En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?  \
# 0                                             Sanción
# 1     Poner en peligro la seguridad de otras personas
# 2     Poner en peligro la seguridad de otras personas
# 3     Poner en peligro la seguridad de otras personas
# 4                                                 NaN
# ..                                                ...
# 89    Poner en peligro la seguridad de otras personas
# 90    Poner en peligro la seguridad de otras personas
# 91                                                NaN
# 92                                                NaN
# 93    Poner en peligro la seguridad de otras personas
#
#    ¿Alguna vez te has comparado con personas a las que sigues en RRSS?  \
# 0                                          Alguna vez
# 1                                          Alguna vez
# 2                                                  Sí
# 3                                          Alguna vez
# 4                                                  Sí
# ..                                                ...
# 89                                                 Sí
# 90                                                 Sí
# 91                                                 No
# 92                                         Alguna vez
# 93                                                 No
#
#    ¿Te has sentido inferior al hacerlo?  \
# 0                            Alguna vez
# 1                                    No
# 2                                    Sí
# 3                            Alguna vez
# 4                                    Sí
# ..                                  ...
# 89                           Alguna vez
# 90                                   Sí
# 91                                  NaN
# 92                                   No
# 93                                   No
#
#    ¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                             Depende
# 4                                                  Sí
# ..                                                ...
# 89                                            Depende
# 90                                                 Sí
# 91                                                 Sí
# 92                                            Depende
# 93                                                 Sí
#
#    ¿Has estado algun periodo de tiempo sin RRSS para desconectar?  \
# 0                                          Una semana
# 1                                          Una semana
# 2                                       Más de un mes
# 3                                       Más de un mes
# 4                                       Más de un mes
# ..                                                ...
# 89                                         Una semana
# 90                                             Un mes
# 91                                             Un mes
# 92                                         Una semana
# 93                                         Una semana
#
#    En caso afirmativo, ¿crees que te benefició?  \
# 0                           En algunos aspectos
# 1                           En algunos aspectos
# 2                                            Sí
# 3                           En algunos aspectos
# 4                                            Sí
# ..                                          ...
# 89                          En algunos aspectos
# 90                                           Sí
# 91                                           Sí
# 92                          En algunos aspectos
# 93                                           Sí
#
#    ¿Consideras que la gente que te rodea goza de una buena salud mental?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  No
# 3                                Lo aparentan pero no
# 4                                Lo aparentan pero no
# ..                                                ...
# 89                                                 Sí
# 90                               Lo aparentan pero no
# 91                               Lo aparentan pero no
# 92                                                 No
# 93                               Lo aparentan pero no
#
#                 Indica el por qué crees que no tienen  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Veo a mucha gente rota. Es una pauta general. ...
# 4                                                 NaN
# ..                                                ...
# 89                                                NaN
# 90                                       Inseguridad
# 91  Falta de autoestima por comparativa ante vidas...
# 92                                           Sociedad
# 93  Porque las RRSS (Tiktok e Instagram sobretodo)...
#
#    ¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?  \
# 0                                           Psicólogo
# 1                                           Psicólogo
# 2                        Me esperaría a que se pasara
# 3                        Me esperaría a que se pasara
# 4                                           Psicólogo
# ..                                                ...
# 89                                          Psicólogo
# 90                                          Psicólogo
# 91                                          Psicólogo
# 92                                          Psicólogo
# 93                                          Psicólogo
#
#    En caso de que ya acudas a uno, ¿te da vergüenza que lo sepa tu círculo?
# 0                                    Depende de quien
# 1                                                  No
# 2                                                  No
# 3                                    Depende de quien
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                NaN
# 92                                                 No
# 93                                                 No
#
# [94 rows x 13 columns]

# %% [markdown]
# 3) Tercer paso

# %%
filtro_edad = resultados_encuesta['Introduce tu edad'] < '35'
resultados_encuesta = resultados_encuesta[filtro_edad]
resultados_encuesta
# Out:
#    Introduce tu edad ¿Tienes carnet de conducir?  \
# 0                 27                          Si
# 1                 29                          Si
# 2                 26                          Si
# 3                 26                          No
# 4                 24                          Si
# ..               ...                         ...
# 88                17                          No
# 89                24                          Si
# 90                19                          Si
# 91                30                          Si
# 93                27                          Si
#
#    ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  No
# ..                                                ...
# 88                                                 No
# 89                                                 No
# 90                                                 No
# 91                                                 No
# 93                                                 Sí
#
#    En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?  \
# 0                                             Sanción
# 1     Poner en peligro la seguridad de otras personas
# 2     Poner en peligro la seguridad de otras personas
# 3     Poner en peligro la seguridad de otras personas
# 4                                                 NaN
# ..                                                ...
# 88                                                NaN
# 89    Poner en peligro la seguridad de otras personas
# 90    Poner en peligro la seguridad de otras personas
# 91                                                NaN
# 93    Poner en peligro la seguridad de otras personas
#
#    ¿Alguna vez te has comparado con personas a las que sigues en RRSS?  \
# 0                                          Alguna vez
# 1                                          Alguna vez
# 2                                                  Sí
# 3                                          Alguna vez
# 4                                                  Sí
# ..                                                ...
# 88                                         Alguna vez
# 89                                                 Sí
# 90                                                 Sí
# 91                                                 No
# 93                                                 No
#
#    ¿Te has sentido inferior al hacerlo?  \
# 0                            Alguna vez
# 1                                    No
# 2                                    Sí
# 3                            Alguna vez
# 4                                    Sí
# ..                                  ...
# 88                           Alguna vez
# 89                           Alguna vez
# 90                                   Sí
# 91                                  NaN
# 93                                   No
#
#    ¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                             Depende
# 4                                                  Sí
# ..                                                ...
# 88                                            Depende
# 89                                            Depende
# 90                                                 Sí
# 91                                                 Sí
# 93                                                 Sí
#
#    ¿Has estado algun periodo de tiempo sin RRSS para desconectar?  \
# 0                                          Una semana
# 1                                          Una semana
# 2                                       Más de un mes
# 3                                       Más de un mes
# 4                                       Más de un mes
# ..                                                ...
# 88                                         Una semana
# 89                                         Una semana
# 90                                             Un mes
# 91                                             Un mes
# 93                                         Una semana
#
#    En caso afirmativo, ¿crees que te benefició?  \
# 0                           En algunos aspectos
# 1                           En algunos aspectos
# 2                                            Sí
# 3                           En algunos aspectos
# 4                                            Sí
# ..                                          ...
# 88                          En algunos aspectos
# 89                          En algunos aspectos
# 90                                           Sí
# 91                                           Sí
# 93                                           Sí
#
#    ¿Consideras que la gente que te rodea goza de una buena salud mental?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  No
# 3                                Lo aparentan pero no
# 4                                Lo aparentan pero no
# ..                                                ...
# 88                               Lo aparentan pero no
# 89                                                 Sí
# 90                               Lo aparentan pero no
# 91                               Lo aparentan pero no
# 93                               Lo aparentan pero no
#
#                 Indica el por qué crees que no tienen  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Veo a mucha gente rota. Es una pauta general. ...
# 4                                                 NaN
# ..                                                ...
# 88    no concuerda lo que dicen con lo que demuestran
# 89                                                NaN
# 90                                       Inseguridad
# 91  Falta de autoestima por comparativa ante vidas...
# 93  Porque las RRSS (Tiktok e Instagram sobretodo)...
#
#    ¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?  \
# 0                                           Psicólogo
# 1                                           Psicólogo
# 2                        Me esperaría a que se pasara
# 3                        Me esperaría a que se pasara
# 4                                           Psicólogo
# ..                                                ...
# 88                                          Psicólogo
# 89                                          Psicólogo
# 90                                          Psicólogo
# 91                                          Psicólogo
# 93                                          Psicólogo
#
#    En caso de que ya acudas a uno, ¿te da vergüenza que lo sepa tu círculo?
# 0                                    Depende de quien
# 1                                                  No
# 2                                                  No
# 3                                    Depende de quien
# 4                                                  No
# ..                                                ...
# 88                                                 No
# 89                                                 No
# 90                                                 No
# 91                                                NaN
# 93                                                 No
#
# [87 rows x 13 columns]

# %% [markdown]
# 4) Cuarto paso

# %%
accidentes_trafico = resultados_encuesta[resultados_encuesta.columns[1:4]]
accidentes_trafico
# Out:
#    ¿Tienes carnet de conducir?  \
# 0                           Si
# 1                           Si
# 2                           Si
# 3                           No
# 4                           Si
# ..                         ...
# 88                          No
# 89                          Si
# 90                          Si
# 91                          Si
# 93                          Si
#
#    ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  No
# ..                                                ...
# 88                                                 No
# 89                                                 No
# 90                                                 No
# 91                                                 No
# 93                                                 Sí
#
#    En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?
# 0                                             Sanción
# 1     Poner en peligro la seguridad de otras personas
# 2     Poner en peligro la seguridad de otras personas
# 3     Poner en peligro la seguridad de otras personas
# 4                                                 NaN
# ..                                                ...
# 88                                                NaN
# 89    Poner en peligro la seguridad de otras personas
# 90    Poner en peligro la seguridad de otras personas
# 91                                                NaN
# 93    Poner en peligro la seguridad de otras personas
#
# [87 rows x 3 columns]

# %% [markdown]
# #### **Análisis de los datos de los resultados de la primera encuesta**
#
# ##### - Tras descartar a los participantes de las edades que se han mencionado anteriormente, nos ha quedado una muestra de 87 personas.

# %%
"""En primer lugar, descartamos a aquellos participantes que no tienen carnet de conducir, 
ya que las respuestas que nos interesan para el estudio son de personas que conducen."""

filtro_conductores = accidentes_trafico['¿Tienes carnet de conducir?'] == 'Si'
accidentes_trafico = accidentes_trafico[filtro_conductores]

"""En segundo lugar, calculamos el porcentaje de participantes que afirman haber hecho uso de un vehículo 
bajo la influencia de alcohol o estupefacientes."""

conduccion_temeraria = accidentes_trafico['¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?'] == 'Sí'
conduccion_temeraria = accidentes_trafico[conduccion_temeraria]

"""En tercer lugar, calculamos el porcentaje de participantes que niegan haber hecho uso de un vehículo bajo 
la influencia de alcohol o estupefacientes."""

conduccion_responsable = accidentes_trafico['¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?'] == 'No'
conduccion_responsable = accidentes_trafico[conduccion_responsable]

"""Por último, calculamos el porcentaje de las causas que más reparo da a los participantes que han conducido un vehículo 
de manera temeraria."""

multa2 = conduccion_temeraria['En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?'] == "Multa"
multa2 = conduccion_temeraria[multa2]

sanción2 = conduccion_temeraria['En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?'] == "Sanción"
sanción2 = conduccion_temeraria[sanción2]

seguridad2 = conduccion_temeraria['En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?'] == "Poner en peligro la seguridad de otras personas"
seguridad2 = conduccion_temeraria[seguridad2]

# %% [markdown]
# #### **Comprobaciones realizadas y conclusiones**

# %% [markdown]
# 1) Primer paso

# %%
"""Tras aplicar el filtro de personas que tienen carnet de conducir, la muestra se reduce a un total de 73 participantes."""
accidentes_trafico.shape
# Out:
# (73, 3)

# %% [markdown]
# 2) Segundo paso

# %%
"""De los 73 participantes, el 56,17% afirma haber conducido bajo los efectos de alcohol o estupefacientes."""
conduccion_temeraria.shape

ct = 41/73
ct = ct*100
ct
# Out:
# 56.16438356164384

# %% [markdown]
# 3. Tercer paso

# %%
"""De los 73 participantes, el 43,83% niega haber conducido bajo los efectos de alcohol o estupefacientes."""
conduccion_responsable.shape

cr = 32/73
cr*100
# Out:
# 43.83561643835616

# %% [markdown]
# 4) Cuarto paso

# %%
"""De los 41 participantes que afirman haber conducido de manera temeraria, el 29,27% de ellos opina que lo que más les frena a hacerlo es la multa económica."""
multa2.shape

multa = 12/41
multa*100
# Out:
# 29.268292682926827

# %%
"""De los 41 participantes que afirman haber conducido de manera temeraria, el 10,96% de ellos opina que lo que más les frena a hacerlo es la sanción."""
sanción2.shape

sanción = 8/73
sanción*100
# Out:
# 10.95890410958904

# %%
"""De los 41 participantes que afirman haber conducido de manera temeraria, el 51,22% de ellos opina que lo que más les frena a hacerlo es poner en peligro la seguridad de otras personas."""
seguridad2.shape

seguridad= 21/41
seguridad*100
# Out:
# 51.21951219512195

# %% [markdown]
# ### ***Resultados de la segunda encuesta efectuada a 50 participantes sobre otros aspectos relacionados con la conducción de vehículos***

# %% [markdown]
# - ##### Abril 2023

# %% [markdown]
# #### **Preguntas realizadas**

# %% [markdown]
# 1) ¿Sueles saltarte semáforos en rojo?
#
# 2) ¿Sueltes sobrepasar el límite de velocidad?
#
# 3) ¿Sueles mirar el móvil mientras conduces?
#
# 4) ¿Has tenido alguna vez un accidente?
#
# 5) En caso afirmativo, ¿puedes indicar el motivo?

# %% [markdown]
# #### **Obtención y análisis de los resultados de la segunda encuesta**

# %%
"""En primer lugar, abrimos el archivo csv donde aparecen recopilados los resultados de la encuesta efectuada
https://docs.google.com/forms/d/19AcuaWmDUW-RAn7l5gAW7bZRs5pIiwTXGhoW3nZt8BM/edit"""

resultados_encuesta2 = pd.read_csv('Encuestaconducción.csv', sep=',')

"""En segundo lugar, descartamos la primera columna, ya que aparecía la marca temporal de las respuestas, datos que 
no resultaban relevantes para el análisis."""

resultados_encuesta2 = resultados_encuesta2.iloc[:, 1:]

"""En tercer lugar, calculamos el porcentaje de participantes que afirman haberse saltado un semáforo en rojo en
alguna ocasión."""

semáforo = resultados_encuesta2['¿Sueles saltarte semáforos en rojo?'] != 'Nunca'
semáforo = resultados_encuesta2[semáforo]

"""En cuarto lugar, calculamos el porcentaje de participantes que afirman sobrepasar el límite de velocidad en
alguna ocasión."""

velocidad = resultados_encuesta2['¿Sueltes sobrepasar el límite de velocidad?'] != 'Nunca'
velocidad = resultados_encuesta2[velocidad]

"""En quinto lugar, calculamos el porcentaje de participantes que afirman mirar el móvil mientras conducen."""

móvil = resultados_encuesta2['¿Sueles mirar el móvil mientras conduces?'] != 'Nunca'
móvil = resultados_encuesta2[móvil]

"""En sexto lugar, calculamos el porcentaje de participantes que afirman haber tenido alguna vez un accidente de tráfico."""

accidente = resultados_encuesta2['¿Has tenido alguna vez un accidente?'] != 'No'
accidente = resultados_encuesta2[accidente]

"""Por último, calculamos el porcentaje que representa cada causa sobre los accidentes de tráfico."""

alcohol_drogas = resultados_encuesta2['En caso afirmativo, ¿puedes indicar el motivo?'] == 'Alcohol y drogas'
alcohol_drogas = resultados_encuesta2[alcohol_drogas]

distracción = resultados_encuesta2['En caso afirmativo, ¿puedes indicar el motivo?'] == 'Distracciones al volante'
distracción = resultados_encuesta2[distracción]

velocidad2 = resultados_encuesta2['En caso afirmativo, ¿puedes indicar el motivo?'] == 'Velocidad'
velocidad2 = resultados_encuesta2[velocidad2]

señalización = resultados_encuesta2['En caso afirmativo, ¿puedes indicar el motivo?'] == 'Ignorar una señalización de tráfico'
señalización = resultados_encuesta2[señalización]

otros = resultados_encuesta2['En caso afirmativo, ¿puedes indicar el motivo?'] == 'Otros'
otros = resultados_encuesta2[otros]

# %% [markdown]
# #### **Comprobaciones realizadas y conclusiones**

# %% [markdown]
# 1) Primer paso

# %%
resultados_encuesta2 = pd.read_csv('Encuestaconducción.csv', sep=',')
resultados_encuesta2
# Out:
#                    Marca temporal ¿Sueles saltarte semáforos en rojo?  \
# 0   2023/04/02 12:59:25 p. m. EET                          Alguna vez
# 1    2023/04/02 1:02:38 p. m. EET                               Nunca
# 2    2023/04/02 1:03:28 p. m. EET                               Nunca
# 3    2023/04/02 1:05:51 p. m. EET                          Alguna vez
# 4    2023/04/02 1:07:03 p. m. EET                               Nunca
# 5    2023/04/02 1:07:48 p. m. EET                               Nunca
# 6    2023/04/02 1:09:13 p. m. EET                          Alguna vez
# 7    2023/04/02 1:12:19 p. m. EET                               Nunca
# 8    2023/04/02 1:13:58 p. m. EET                      Ocasionalmente
# 9    2023/04/02 1:15:10 p. m. EET                               Nunca
# 10   2023/04/02 1:18:56 p. m. EET                               Nunca
# 11   2023/04/02 1:20:21 p. m. EET                               Nunca
# 12   2023/04/02 1:23:29 p. m. EET                               Nunca
# 13   2023/04/02 1:43:42 p. m. EET                          Alguna vez
# 14   2023/04/02 1:47:38 p. m. EET                               Nunca
# 15   2023/04/02 1:49:21 p. m. EET                      Ocasionalmente
# 16   2023/04/02 2:06:02 p. m. EET                          Alguna vez
# 17   2023/04/02 2:06:57 p. m. EET                          Alguna vez
# 18   2023/04/02 2:08:08 p. m. EET                          Alguna vez
# 19   2023/04/02 2:13:45 p. m. EET                               Nunca
# 20   2023/04/02 2:15:48 p. m. EET                               Nunca
# 21   2023/04/02 2:18:03 p. m. EET                               Nunca
# 22   2023/04/02 2:26:15 p. m. EET                               Nunca
# 23   2023/04/02 2:27:51 p. m. EET                               Nunca
# 24   2023/04/02 2:33:29 p. m. EET                               Nunca
# 25   2023/04/02 2:38:16 p. m. EET                               Nunca
# 26   2023/04/02 3:05:36 p. m. EET                               Nunca
# 27   2023/04/02 3:06:54 p. m. EET                               Nunca
# 28   2023/04/02 3:36:10 p. m. EET                          Alguna vez
# 29   2023/04/02 3:39:23 p. m. EET                          Alguna vez
# 30   2023/04/02 3:59:04 p. m. EET                               Nunca
# 31   2023/04/02 3:59:45 p. m. EET                          Alguna vez
# 32   2023/04/02 4:08:49 p. m. EET                               Nunca
# 33   2023/04/02 4:53:10 p. m. EET                               Nunca
# 34   2023/04/02 5:18:49 p. m. EET                          Alguna vez
# 35   2023/04/02 5:50:13 p. m. EET                               Nunca
# 36   2023/04/02 6:47:46 p. m. EET                               Nunca
# 37   2023/04/02 7:17:10 p. m. EET                      Ocasionalmente
# 38   2023/04/02 9:19:30 p. m. EET                      Frecuentemente
# 39   2023/04/02 9:32:34 p. m. EET                               Nunca
# 40   2023/04/02 9:33:53 p. m. EET                               Nunca
# 41   2023/04/02 9:38:51 p. m. EET                          Alguna vez
# 42  2023/04/02 11:39:06 p. m. EET                          Alguna vez
# 43   2023/04/03 6:33:02 a. m. EET                               Nunca
# 44   2023/04/03 7:58:28 a. m. EET                          Alguna vez
# 45   2023/04/03 8:09:26 a. m. EET                               Nunca
# 46   2023/04/03 8:21:25 a. m. EET                          Alguna vez
# 47   2023/04/03 8:40:08 a. m. EET                      Ocasionalmente
# 48   2023/04/03 8:53:13 a. m. EET                               Nunca
# 49   2023/04/03 9:05:32 a. m. EET                          Alguna vez
#
#    ¿Sueltes sobrepasar el límite de velocidad?  \
# 0                                   Alguna vez
# 1                                   Alguna vez
# 2                               Frecuentemente
# 3                               Ocasionalmente
# 4                               Frecuentemente
# 5                                   Alguna vez
# 6                               Frecuentemente
# 7                                   Alguna vez
# 8                                        Nunca
# 9                                   Alguna vez
# 10                                  Alguna vez
# 11                              Ocasionalmente
# 12                              Frecuentemente
# 13                                  Alguna vez
# 14                                       Nunca
# 15                              Ocasionalmente
# 16                              Frecuentemente
# 17                                  Alguna vez
# 18                                       Nunca
# 19                                       Nunca
# 20                              Frecuentemente
# 21                                  Alguna vez
# 22                                  Alguna vez
# 23                                  Alguna vez
# 24                                       Nunca
# 25                              Ocasionalmente
# 26                                  Alguna vez
# 27                              Frecuentemente
# 28                                  Alguna vez
# 29                              Frecuentemente
# 30                              Frecuentemente
# 31                              Frecuentemente
# 32                                  Alguna vez
# 33                                  Alguna vez
# 34                                  Alguna vez
# 35                              Frecuentemente
# 36                                  Alguna vez
# 37                              Ocasionalmente
# 38                              Frecuentemente
# 39                              Frecuentemente
# 40                                  Alguna vez
# 41                              Frecuentemente
# 42                              Ocasionalmente
# 43                              Frecuentemente
# 44                              Frecuentemente
# 45                                       Nunca
# 46                              Frecuentemente
# 47                              Ocasionalmente
# 48                                       Nunca
# 49                                  Alguna vez
#
#    ¿Sueles mirar el móvil mientras conduces?  \
# 0                                 Alguna vez
# 1                                      Nunca
# 2                                 Alguna vez
# 3                             Ocasionalmente
# 4                                 Alguna vez
# 5                                      Nunca
# 6                             Frecuentemente
# 7                                      Nunca
# 8                                 Alguna vez
# 9                                      Nunca
# 10                                Alguna vez
# 11                                Alguna vez
# 12                                Alguna vez
# 13                                Alguna vez
# 14                                Alguna vez
# 15                            Ocasionalmente
# 16                            Frecuentemente
# 17                            Frecuentemente
# 18                                     Nunca
# 19                                     Nunca
# 20                                Alguna vez
# 21                                Alguna vez
# 22                                     Nunca
# 23                                     Nunca
# 24                                     Nunca
# 25                                Alguna vez
# 26                                Alguna vez
# 27                                Alguna vez
# 28                                     Nunca
# 29                                Alguna vez
# 30                                     Nunca
# 31                                Alguna vez
# 32                                     Nunca
# 33                                Alguna vez
# 34                                Alguna vez
# 35                                Alguna vez
# 36                                     Nunca
# 37                            Ocasionalmente
# 38                            Ocasionalmente
# 39                            Ocasionalmente
# 40                                Alguna vez
# 41                                Alguna vez
# 42                            Frecuentemente
# 43                            Frecuentemente
# 44                                Alguna vez
# 45                                Alguna vez
# 46                                     Nunca
# 47                            Ocasionalmente
# 48                                     Nunca
# 49                                Alguna vez
#
#    ¿Has tenido alguna vez un accidente?  \
# 0                                    No
# 1                                    Sí
# 2                                    No
# 3                                    Sí
# 4                                    Sí
# 5                                    No
# 6                                    Sí
# 7                                    No
# 8                                    No
# 9                                    Sí
# 10                                   No
# 11                                   Sí
# 12                                   No
# 13                                   No
# 14                                   No
# 15                                   No
# 16                                   No
# 17                                   No
# 18                                   No
# 19                                   No
# 20                                   No
# 21                                   No
# 22                                   No
# 23                                   Sí
# 24                                   No
# 25                                   No
# 26                                   No
# 27                                   Sí
# 28                                   No
# 29                                   No
# 30                                   No
# 31                                   Sí
# 32                                   Sí
# 33                                   No
# 34                                   No
# 35                                   Sí
# 36                                   No
# 37                                   No
# 38                                   No
# 39                                   No
# 40                                   Sí
# 41                                   No
# 42                                   No
# 43                                   Sí
# 44                                   Sí
# 45                                   Sí
# 46                                   Sí
# 47                                   No
# 48                                   No
# 49                                   No
#
#    En caso afirmativo, ¿puedes indicar el motivo?
# 0                                             NaN
# 1                                           Otros
# 2                                             NaN
# 3                                           Otros
# 4                        Distracciones al volante
# 5                                             NaN
# 6                                       Velocidad
# 7                                             NaN
# 8                                             NaN
# 9                                           Otros
# 10                                            NaN
# 11                                          Otros
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                          Otros
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23            Ignorar una señalización de tráfico
# 24                                          Otros
# 25                                            NaN
# 26                                            NaN
# 27                                          Otros
# 28                                          Otros
# 29                                            NaN
# 30                                            NaN
# 31                                          Otros
# 32            Ignorar una señalización de tráfico
# 33                                            NaN
# 34                                            NaN
# 35                                          Otros
# 36                                            NaN
# 37                                            NaN
# 38                                            NaN
# 39                                          Otros
# 40                                          Otros
# 41                                            NaN
# 42                                          Otros
# 43                               Alcohol y drogas
# 44            Ignorar una señalización de tráfico
# 45                       Distracciones al volante
# 46                                          Otros
# 47                                            NaN
# 48                                            NaN
# 49                                            NaN

# %% [markdown]
# 2) Segundo paso

# %%
resultados_encuesta2 = resultados_encuesta2.iloc[:, 1:] 
resultados_encuesta2
# Out:
#    ¿Sueles saltarte semáforos en rojo?  \
# 0                           Alguna vez
# 1                                Nunca
# 2                                Nunca
# 3                           Alguna vez
# 4                                Nunca
# 5                                Nunca
# 6                           Alguna vez
# 7                                Nunca
# 8                       Ocasionalmente
# 9                                Nunca
# 10                               Nunca
# 11                               Nunca
# 12                               Nunca
# 13                          Alguna vez
# 14                               Nunca
# 15                      Ocasionalmente
# 16                          Alguna vez
# 17                          Alguna vez
# 18                          Alguna vez
# 19                               Nunca
# 20                               Nunca
# 21                               Nunca
# 22                               Nunca
# 23                               Nunca
# 24                               Nunca
# 25                               Nunca
# 26                               Nunca
# 27                               Nunca
# 28                          Alguna vez
# 29                          Alguna vez
# 30                               Nunca
# 31                          Alguna vez
# 32                               Nunca
# 33                               Nunca
# 34                          Alguna vez
# 35                               Nunca
# 36                               Nunca
# 37                      Ocasionalmente
# 38                      Frecuentemente
# 39                               Nunca
# 40                               Nunca
# 41                          Alguna vez
# 42                          Alguna vez
# 43                               Nunca
# 44                          Alguna vez
# 45                               Nunca
# 46                          Alguna vez
# 47                      Ocasionalmente
# 48                               Nunca
# 49                          Alguna vez
#
#    ¿Sueltes sobrepasar el límite de velocidad?  \
# 0                                   Alguna vez
# 1                                   Alguna vez
# 2                               Frecuentemente
# 3                               Ocasionalmente
# 4                               Frecuentemente
# 5                                   Alguna vez
# 6                               Frecuentemente
# 7                                   Alguna vez
# 8                                        Nunca
# 9                                   Alguna vez
# 10                                  Alguna vez
# 11                              Ocasionalmente
# 12                              Frecuentemente
# 13                                  Alguna vez
# 14                                       Nunca
# 15                              Ocasionalmente
# 16                              Frecuentemente
# 17                                  Alguna vez
# 18                                       Nunca
# 19                                       Nunca
# 20                              Frecuentemente
# 21                                  Alguna vez
# 22                                  Alguna vez
# 23                                  Alguna vez
# 24                                       Nunca
# 25                              Ocasionalmente
# 26                                  Alguna vez
# 27                              Frecuentemente
# 28                                  Alguna vez
# 29                              Frecuentemente
# 30                              Frecuentemente
# 31                              Frecuentemente
# 32                                  Alguna vez
# 33                                  Alguna vez
# 34                                  Alguna vez
# 35                              Frecuentemente
# 36                                  Alguna vez
# 37                              Ocasionalmente
# 38                              Frecuentemente
# 39                              Frecuentemente
# 40                                  Alguna vez
# 41                              Frecuentemente
# 42                              Ocasionalmente
# 43                              Frecuentemente
# 44                              Frecuentemente
# 45                                       Nunca
# 46                              Frecuentemente
# 47                              Ocasionalmente
# 48                                       Nunca
# 49                                  Alguna vez
#
#    ¿Sueles mirar el móvil mientras conduces?  \
# 0                                 Alguna vez
# 1                                      Nunca
# 2                                 Alguna vez
# 3                             Ocasionalmente
# 4                                 Alguna vez
# 5                                      Nunca
# 6                             Frecuentemente
# 7                                      Nunca
# 8                                 Alguna vez
# 9                                      Nunca
# 10                                Alguna vez
# 11                                Alguna vez
# 12                                Alguna vez
# 13                                Alguna vez
# 14                                Alguna vez
# 15                            Ocasionalmente
# 16                            Frecuentemente
# 17                            Frecuentemente
# 18                                     Nunca
# 19                                     Nunca
# 20                                Alguna vez
# 21                                Alguna vez
# 22                                     Nunca
# 23                                     Nunca
# 24                                     Nunca
# 25                                Alguna vez
# 26                                Alguna vez
# 27                                Alguna vez
# 28                                     Nunca
# 29                                Alguna vez
# 30                                     Nunca
# 31                                Alguna vez
# 32                                     Nunca
# 33                                Alguna vez
# 34                                Alguna vez
# 35                                Alguna vez
# 36                                     Nunca
# 37                            Ocasionalmente
# 38                            Ocasionalmente
# 39                            Ocasionalmente
# 40                                Alguna vez
# 41                                Alguna vez
# 42                            Frecuentemente
# 43                            Frecuentemente
# 44                                Alguna vez
# 45                                Alguna vez
# 46                                     Nunca
# 47                            Ocasionalmente
# 48                                     Nunca
# 49                                Alguna vez
#
#    ¿Has tenido alguna vez un accidente?  \
# 0                                    No
# 1                                    Sí
# 2                                    No
# 3                                    Sí
# 4                                    Sí
# 5                                    No
# 6                                    Sí
# 7                                    No
# 8                                    No
# 9                                    Sí
# 10                                   No
# 11                                   Sí
# 12                                   No
# 13                                   No
# 14                                   No
# 15                                   No
# 16                                   No
# 17                                   No
# 18                                   No
# 19                                   No
# 20                                   No
# 21                                   No
# 22                                   No
# 23                                   Sí
# 24                                   No
# 25                                   No
# 26                                   No
# 27                                   Sí
# 28                                   No
# 29                                   No
# 30                                   No
# 31                                   Sí
# 32                                   Sí
# 33                                   No
# 34                                   No
# 35                                   Sí
# 36                                   No
# 37                                   No
# 38                                   No
# 39                                   No
# 40                                   Sí
# 41                                   No
# 42                                   No
# 43                                   Sí
# 44                                   Sí
# 45                                   Sí
# 46                                   Sí
# 47                                   No
# 48                                   No
# 49                                   No
#
#    En caso afirmativo, ¿puedes indicar el motivo?
# 0                                             NaN
# 1                                           Otros
# 2                                             NaN
# 3                                           Otros
# 4                        Distracciones al volante
# 5                                             NaN
# 6                                       Velocidad
# 7                                             NaN
# 8                                             NaN
# 9                                           Otros
# 10                                            NaN
# 11                                          Otros
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                          Otros
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23            Ignorar una señalización de tráfico
# 24                                          Otros
# 25                                            NaN
# 26                                            NaN
# 27                                          Otros
# 28                                          Otros
# 29                                            NaN
# 30                                            NaN
# 31                                          Otros
# 32            Ignorar una señalización de tráfico
# 33                                            NaN
# 34                                            NaN
# 35                                          Otros
# 36                                            NaN
# 37                                            NaN
# 38                                            NaN
# 39                                          Otros
# 40                                          Otros
# 41                                            NaN
# 42                                          Otros
# 43                               Alcohol y drogas
# 44            Ignorar una señalización de tráfico
# 45                       Distracciones al volante
# 46                                          Otros
# 47                                            NaN
# 48                                            NaN
# 49                                            NaN

# %% [markdown]
# 3) Tercer paso

# %%
semáforo = resultados_encuesta2['¿Sueles saltarte semáforos en rojo?'] != 'Nunca'
semáforo = resultados_encuesta2[semáforo]
semáforo.shape

"""De los 50 participantes, el 42% afirma haberse saltado un semáforo en rojo en alguna ocasión."""

ss = 21/50
ss = ss*100
ss
# Out:
# 42.0

# %% [markdown]
# 4) Cuarto paso

# %%
velocidad = resultados_encuesta2['¿Sueltes sobrepasar el límite de velocidad?'] != 'Nunca'
velocidad = resultados_encuesta2[velocidad]
velocidad.shape

"""De los 50 participantes, el 86% afirma haber sobrepasado el límite de velocidad en alguna ocasión."""

vv = 43/50
vv = vv*100
vv
# Out:
# 86.0

# %% [markdown]
# 5) Quinto paso

# %%
móvil = resultados_encuesta2['¿Sueles mirar el móvil mientras conduces?'] != 'Nunca'
móvil = resultados_encuesta2[móvil]
móvil.shape

"""De los 50 participantes, el 70% afirma haber utilizado dispositivos móviles mientras conducían en alguna ocasión."""

mm = 35/50
mm = mm*100
mm
# Out:
# 70.0

# %% [markdown]
# 6) Sexto paso

# %%
accidente = resultados_encuesta2['¿Has tenido alguna vez un accidente?'] != 'No'
accidente = resultados_encuesta2[accidente]
accidente.shape

"""De los 50 participantes, el 32% afirma haber tenido un accidente de tráfico en alguna ocasión."""

acc = 16/50
acc = acc*100
acc
# Out:
# 32.0

# %% [markdown]
# 7) Séptimo paso

# %%
alcohol_drogas = resultados_encuesta2['En caso afirmativo, ¿puedes indicar el motivo?'] == 'Alcohol y drogas'
alcohol_drogas = resultados_encuesta2[alcohol_drogas]
alcohol_drogas.shape

"""De los 16 participantes que afirman haber tenido un accidente de tráfico, el 6.25% afirma que fue provocado por el consumo de alcohol y/o drogas."""

accd = 1/16
accd = accd*100
accd
# Out:
# 6.25

# %%
distracción = resultados_encuesta2['En caso afirmativo, ¿puedes indicar el motivo?'] == 'Distracciones al volante'
distracción = resultados_encuesta2[distracción]
distracción.shape

"""De los 16 participantes que afirman haber tenido un accidente de tráfico, el 12.5% afirma que fue provocado por una distracción al volante."""

accds = 2/16
accds = accds*100
accds
# Out:
# 12.5

# %%
velocidad2 = resultados_encuesta2['En caso afirmativo, ¿puedes indicar el motivo?'] == 'Velocidad'
velocidad2 = resultados_encuesta2[velocidad2]
velocidad2.shape

"""De los 16 participantes que afirman haber tenido un accidente de tráfico, el 6.25% afirma que fue provocado por sobrepasar el límite de velocidad."""

accv = 1/16
accv = accv*100
accv
# Out:
# 6.25

# %%
señalización = resultados_encuesta2['En caso afirmativo, ¿puedes indicar el motivo?'] == 'Ignorar una señalización de tráfico'
señalización = resultados_encuesta2[señalización]
señalización.shape

"""De los 16 participantes que afirman haber tenido un accidente de tráfico, el 12.5% afirma que fue provocado por ignorar una señalización de tráfico."""

accdst = 2/16
accdst = accdst*100
accdst
# Out:
# 12.5

# %%
otros = resultados_encuesta2['En caso afirmativo, ¿puedes indicar el motivo?'] == 'Otros'
otros = resultados_encuesta2[otros]
otros.shape

"""De los 16 participantes que afirman haber tenido un accidente de tráfico, el 68.75% afirma que fue provocado por otros motivos."""

ac = 11/16
ac = ac*100
ac
# Out:
# 68.75
