# %% [markdown]
# # ***Resultados de la encuesta efectuada a 100 participantes sobre salud mental y RRSS***

# %% [markdown]
# #### **Preguntas realizadas**

# %% [markdown]
# 1) ¿Alguna vez te has comparado con personas a las que sigues en RRSS?
#
# 2) ¿Te has sentido inferior al hacerlo?
#
# 3) ¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?
#
# 4) ¿Has estado algun periodo de tiempo sin RRSS para desconectar?
#
# 5) En caso afirmativo, ¿crees que te benefició?
#
# 6) ¿Consideras que la gente que te rodea goza de una buena salud mental?
#
# 7) ¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?

# %% [markdown]
# #### **Obtención de los resultados de la encuesta**

# %%
import pandas as pd

# %%
"""En primer lugar, abrimos el archivo csv donde aparecen recopilados los resultados de la encuesta efectuada
https://docs.google.com/spreadsheets/d/1espVWoKwtwFrv8hBeUP1q_k0yeCzYwbzXngXrI0uWNM/edit#gid=998776026""" 

resultados_encuesta = pd.read_csv('resultados_encuesta.csv', sep = ',')

"""En segundo lugar, descartamos las dos primeras columnas, ya que aparecía la marca temporal de las respuestas 
y la puntuación obtenida de las mismas, datos que no resultaban relevantes para el análisis."""

resultados_encuesta = resultados_encuesta[resultados_encuesta.columns[2:-1]]

"""En tercer lugar, descartamos las respuestas de participantes mayores a 34 años, ya que interesa conocer 
únicamente las respuestas de los participantes menores de 34 años."""

filtro_edad = resultados_encuesta['Introduce tu edad'] < '35'
resultados_encuesta = resultados_encuesta[filtro_edad]

"""En cuarto lugar, dividimos los resultados de la encuesta en dos partes: conducción y RRSSS. Para este caso, 
necesitamos los datos que aparecen a partir de la cuarta columna, ya que son las que contienen información relacionada
con la salud mental y el uso delas RRSS."""

saludmental_RRSS = resultados_encuesta[resultados_encuesta.columns[4:-1]]

# %% [markdown]
# 1) Primer paso

# %%
resultados_encuesta = pd.read_csv('resultados_encuesta.csv', sep = ',')
resultados_encuesta
# Out:
#          Marca temporal  Puntuación Introduce tu edad  \
# 0    15/03/2023 0:05:02         NaN                27
# 1    15/03/2023 0:09:26         NaN                29
# 2    15/03/2023 0:10:04         NaN                26
# 3    15/03/2023 0:10:16         NaN                26
# 4    15/03/2023 0:11:15         NaN                24
# ..                  ...         ...               ...
# 89  15/03/2023 14:13:45         NaN                24
# 90  15/03/2023 16:14:10         NaN                19
# 91  15/03/2023 16:24:33         NaN                30
# 92  15/03/2023 16:55:35         NaN            Miguel
# 93   16/03/2023 7:14:27         NaN                27
#
#    ¿Tienes carnet de conducir?  \
# 0                           Si
# 1                           Si
# 2                           Si
# 3                           No
# 4                           Si
# ..                         ...
# 89                          Si
# 90                          Si
# 91                          Si
# 92                          No
# 93                          Si
#
#    ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                 No
# 92                                                 No
# 93                                                 Sí
#
#    En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?  \
# 0                                             Sanción
# 1     Poner en peligro la seguridad de otras personas
# 2     Poner en peligro la seguridad de otras personas
# 3     Poner en peligro la seguridad de otras personas
# 4                                                 NaN
# ..                                                ...
# 89    Poner en peligro la seguridad de otras personas
# 90    Poner en peligro la seguridad de otras personas
# 91                                                NaN
# 92                                                NaN
# 93    Poner en peligro la seguridad de otras personas
#
#    ¿Alguna vez te has comparado con personas a las que sigues en RRSS?  \
# 0                                          Alguna vez
# 1                                          Alguna vez
# 2                                                  Sí
# 3                                          Alguna vez
# 4                                                  Sí
# ..                                                ...
# 89                                                 Sí
# 90                                                 Sí
# 91                                                 No
# 92                                         Alguna vez
# 93                                                 No
#
#    ¿Te has sentido inferior al hacerlo?  \
# 0                            Alguna vez
# 1                                    No
# 2                                    Sí
# 3                            Alguna vez
# 4                                    Sí
# ..                                  ...
# 89                           Alguna vez
# 90                                   Sí
# 91                                  NaN
# 92                                   No
# 93                                   No
#
#    ¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                             Depende
# 4                                                  Sí
# ..                                                ...
# 89                                            Depende
# 90                                                 Sí
# 91                                                 Sí
# 92                                            Depende
# 93                                                 Sí
#
#    ¿Has estado algun periodo de tiempo sin RRSS para desconectar?  \
# 0                                          Una semana
# 1                                          Una semana
# 2                                       Más de un mes
# 3                                       Más de un mes
# 4                                       Más de un mes
# ..                                                ...
# 89                                         Una semana
# 90                                             Un mes
# 91                                             Un mes
# 92                                         Una semana
# 93                                         Una semana
#
#    En caso afirmativo, ¿crees que te benefició?  \
# 0                           En algunos aspectos
# 1                           En algunos aspectos
# 2                                            Sí
# 3                           En algunos aspectos
# 4                                            Sí
# ..                                          ...
# 89                          En algunos aspectos
# 90                                           Sí
# 91                                           Sí
# 92                          En algunos aspectos
# 93                                           Sí
#
#    ¿Consideras que la gente que te rodea goza de una buena salud mental?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  No
# 3                                Lo aparentan pero no
# 4                                Lo aparentan pero no
# ..                                                ...
# 89                                                 Sí
# 90                               Lo aparentan pero no
# 91                               Lo aparentan pero no
# 92                                                 No
# 93                               Lo aparentan pero no
#
#                 Indica el por qué crees que no tienen  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Veo a mucha gente rota. Es una pauta general. ...
# 4                                                 NaN
# ..                                                ...
# 89                                                NaN
# 90                                       Inseguridad
# 91  Falta de autoestima por comparativa ante vidas...
# 92                                           Sociedad
# 93  Porque las RRSS (Tiktok e Instagram sobretodo)...
#
#    ¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?  \
# 0                                           Psicólogo
# 1                                           Psicólogo
# 2                        Me esperaría a que se pasara
# 3                        Me esperaría a que se pasara
# 4                                           Psicólogo
# ..                                                ...
# 89                                          Psicólogo
# 90                                          Psicólogo
# 91                                          Psicólogo
# 92                                          Psicólogo
# 93                                          Psicólogo
#
#    En caso de que ya acudas a uno, ¿te da vergüenza que lo sepa tu círculo?
# 0                                    Depende de quien
# 1                                                  No
# 2                                                  No
# 3                                    Depende de quien
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                NaN
# 92                                                 No
# 93                                                 No
#
# [94 rows x 15 columns]

# %% [markdown]
# 2) Segundo paso

# %%
resultados_encuesta = resultados_encuesta[resultados_encuesta.columns[2:]]
resultados_encuesta
# Out:
#    Introduce tu edad ¿Tienes carnet de conducir?  \
# 0                 27                          Si
# 1                 29                          Si
# 2                 26                          Si
# 3                 26                          No
# 4                 24                          Si
# ..               ...                         ...
# 89                24                          Si
# 90                19                          Si
# 91                30                          Si
# 92            Miguel                          No
# 93                27                          Si
#
#    ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                 No
# 92                                                 No
# 93                                                 Sí
#
#    En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?  \
# 0                                             Sanción
# 1     Poner en peligro la seguridad de otras personas
# 2     Poner en peligro la seguridad de otras personas
# 3     Poner en peligro la seguridad de otras personas
# 4                                                 NaN
# ..                                                ...
# 89    Poner en peligro la seguridad de otras personas
# 90    Poner en peligro la seguridad de otras personas
# 91                                                NaN
# 92                                                NaN
# 93    Poner en peligro la seguridad de otras personas
#
#    ¿Alguna vez te has comparado con personas a las que sigues en RRSS?  \
# 0                                          Alguna vez
# 1                                          Alguna vez
# 2                                                  Sí
# 3                                          Alguna vez
# 4                                                  Sí
# ..                                                ...
# 89                                                 Sí
# 90                                                 Sí
# 91                                                 No
# 92                                         Alguna vez
# 93                                                 No
#
#    ¿Te has sentido inferior al hacerlo?  \
# 0                            Alguna vez
# 1                                    No
# 2                                    Sí
# 3                            Alguna vez
# 4                                    Sí
# ..                                  ...
# 89                           Alguna vez
# 90                                   Sí
# 91                                  NaN
# 92                                   No
# 93                                   No
#
#    ¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                             Depende
# 4                                                  Sí
# ..                                                ...
# 89                                            Depende
# 90                                                 Sí
# 91                                                 Sí
# 92                                            Depende
# 93                                                 Sí
#
#    ¿Has estado algun periodo de tiempo sin RRSS para desconectar?  \
# 0                                          Una semana
# 1                                          Una semana
# 2                                       Más de un mes
# 3                                       Más de un mes
# 4                                       Más de un mes
# ..                                                ...
# 89                                         Una semana
# 90                                             Un mes
# 91                                             Un mes
# 92                                         Una semana
# 93                                         Una semana
#
#    En caso afirmativo, ¿crees que te benefició?  \
# 0                           En algunos aspectos
# 1                           En algunos aspectos
# 2                                            Sí
# 3                           En algunos aspectos
# 4                                            Sí
# ..                                          ...
# 89                          En algunos aspectos
# 90                                           Sí
# 91                                           Sí
# 92                          En algunos aspectos
# 93                                           Sí
#
#    ¿Consideras que la gente que te rodea goza de una buena salud mental?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  No
# 3                                Lo aparentan pero no
# 4                                Lo aparentan pero no
# ..                                                ...
# 89                                                 Sí
# 90                               Lo aparentan pero no
# 91                               Lo aparentan pero no
# 92                                                 No
# 93                               Lo aparentan pero no
#
#                 Indica el por qué crees que no tienen  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Veo a mucha gente rota. Es una pauta general. ...
# 4                                                 NaN
# ..                                                ...
# 89                                                NaN
# 90                                       Inseguridad
# 91  Falta de autoestima por comparativa ante vidas...
# 92                                           Sociedad
# 93  Porque las RRSS (Tiktok e Instagram sobretodo)...
#
#    ¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?  \
# 0                                           Psicólogo
# 1                                           Psicólogo
# 2                        Me esperaría a que se pasara
# 3                        Me esperaría a que se pasara
# 4                                           Psicólogo
# ..                                                ...
# 89                                          Psicólogo
# 90                                          Psicólogo
# 91                                          Psicólogo
# 92                                          Psicólogo
# 93                                          Psicólogo
#
#    En caso de que ya acudas a uno, ¿te da vergüenza que lo sepa tu círculo?
# 0                                    Depende de quien
# 1                                                  No
# 2                                                  No
# 3                                    Depende de quien
# 4                                                  No
# ..                                                ...
# 89                                                 No
# 90                                                 No
# 91                                                NaN
# 92                                                 No
# 93                                                 No
#
# [94 rows x 13 columns]

# %% [markdown]
# 3) Tercer paso

# %%
filtro_edad = resultados_encuesta['Introduce tu edad'] < '35'
resultados_encuesta = resultados_encuesta[filtro_edad]
resultados_encuesta
# Out:
#    Introduce tu edad ¿Tienes carnet de conducir?  \
# 0                 27                          Si
# 1                 29                          Si
# 2                 26                          Si
# 3                 26                          No
# 4                 24                          Si
# ..               ...                         ...
# 88                17                          No
# 89                24                          Si
# 90                19                          Si
# 91                30                          Si
# 93                27                          Si
#
#    ¿Has conducido alguna vez bajo los efectos del alcohol o estupefacientes?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                                  Sí
# 4                                                  No
# ..                                                ...
# 88                                                 No
# 89                                                 No
# 90                                                 No
# 91                                                 No
# 93                                                 Sí
#
#    En caso afirmativo, ¿qué es lo que mas reparo te da cuando lo haces?  \
# 0                                             Sanción
# 1     Poner en peligro la seguridad de otras personas
# 2     Poner en peligro la seguridad de otras personas
# 3     Poner en peligro la seguridad de otras personas
# 4                                                 NaN
# ..                                                ...
# 88                                                NaN
# 89    Poner en peligro la seguridad de otras personas
# 90    Poner en peligro la seguridad de otras personas
# 91                                                NaN
# 93    Poner en peligro la seguridad de otras personas
#
#    ¿Alguna vez te has comparado con personas a las que sigues en RRSS?  \
# 0                                          Alguna vez
# 1                                          Alguna vez
# 2                                                  Sí
# 3                                          Alguna vez
# 4                                                  Sí
# ..                                                ...
# 88                                         Alguna vez
# 89                                                 Sí
# 90                                                 Sí
# 91                                                 No
# 93                                                 No
#
#    ¿Te has sentido inferior al hacerlo?  \
# 0                            Alguna vez
# 1                                    No
# 2                                    Sí
# 3                            Alguna vez
# 4                                    Sí
# ..                                  ...
# 88                           Alguna vez
# 89                           Alguna vez
# 90                                   Sí
# 91                                  NaN
# 93                                   No
#
#    ¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                             Depende
# 4                                                  Sí
# ..                                                ...
# 88                                            Depende
# 89                                            Depende
# 90                                                 Sí
# 91                                                 Sí
# 93                                                 Sí
#
#    ¿Has estado algun periodo de tiempo sin RRSS para desconectar?  \
# 0                                          Una semana
# 1                                          Una semana
# 2                                       Más de un mes
# 3                                       Más de un mes
# 4                                       Más de un mes
# ..                                                ...
# 88                                         Una semana
# 89                                         Una semana
# 90                                             Un mes
# 91                                             Un mes
# 93                                         Una semana
#
#    En caso afirmativo, ¿crees que te benefició?  \
# 0                           En algunos aspectos
# 1                           En algunos aspectos
# 2                                            Sí
# 3                           En algunos aspectos
# 4                                            Sí
# ..                                          ...
# 88                          En algunos aspectos
# 89                          En algunos aspectos
# 90                                           Sí
# 91                                           Sí
# 93                                           Sí
#
#    ¿Consideras que la gente que te rodea goza de una buena salud mental?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  No
# 3                                Lo aparentan pero no
# 4                                Lo aparentan pero no
# ..                                                ...
# 88                               Lo aparentan pero no
# 89                                                 Sí
# 90                               Lo aparentan pero no
# 91                               Lo aparentan pero no
# 93                               Lo aparentan pero no
#
#                 Indica el por qué crees que no tienen  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Veo a mucha gente rota. Es una pauta general. ...
# 4                                                 NaN
# ..                                                ...
# 88    no concuerda lo que dicen con lo que demuestran
# 89                                                NaN
# 90                                       Inseguridad
# 91  Falta de autoestima por comparativa ante vidas...
# 93  Porque las RRSS (Tiktok e Instagram sobretodo)...
#
#    ¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?  \
# 0                                           Psicólogo
# 1                                           Psicólogo
# 2                        Me esperaría a que se pasara
# 3                        Me esperaría a que se pasara
# 4                                           Psicólogo
# ..                                                ...
# 88                                          Psicólogo
# 89                                          Psicólogo
# 90                                          Psicólogo
# 91                                          Psicólogo
# 93                                          Psicólogo
#
#    En caso de que ya acudas a uno, ¿te da vergüenza que lo sepa tu círculo?
# 0                                    Depende de quien
# 1                                                  No
# 2                                                  No
# 3                                    Depende de quien
# 4                                                  No
# ..                                                ...
# 88                                                 No
# 89                                                 No
# 90                                                 No
# 91                                                NaN
# 93                                                 No
#
# [87 rows x 13 columns]

# %% [markdown]
# 4) Cuarto paso

# %%
saludmental_RRSS = resultados_encuesta[resultados_encuesta.columns[4:-1]]
saludmental_RRSS
# Out:
#    ¿Alguna vez te has comparado con personas a las que sigues en RRSS?  \
# 0                                          Alguna vez
# 1                                          Alguna vez
# 2                                                  Sí
# 3                                          Alguna vez
# 4                                                  Sí
# ..                                                ...
# 88                                         Alguna vez
# 89                                                 Sí
# 90                                                 Sí
# 91                                                 No
# 93                                                 No
#
#    ¿Te has sentido inferior al hacerlo?  \
# 0                            Alguna vez
# 1                                    No
# 2                                    Sí
# 3                            Alguna vez
# 4                                    Sí
# ..                                  ...
# 88                           Alguna vez
# 89                           Alguna vez
# 90                                   Sí
# 91                                  NaN
# 93                                   No
#
#    ¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  Sí
# 3                                             Depende
# 4                                                  Sí
# ..                                                ...
# 88                                            Depende
# 89                                            Depende
# 90                                                 Sí
# 91                                                 Sí
# 93                                                 Sí
#
#    ¿Has estado algun periodo de tiempo sin RRSS para desconectar?  \
# 0                                          Una semana
# 1                                          Una semana
# 2                                       Más de un mes
# 3                                       Más de un mes
# 4                                       Más de un mes
# ..                                                ...
# 88                                         Una semana
# 89                                         Una semana
# 90                                             Un mes
# 91                                             Un mes
# 93                                         Una semana
#
#    En caso afirmativo, ¿crees que te benefició?  \
# 0                           En algunos aspectos
# 1                           En algunos aspectos
# 2                                            Sí
# 3                           En algunos aspectos
# 4                                            Sí
# ..                                          ...
# 88                          En algunos aspectos
# 89                          En algunos aspectos
# 90                                           Sí
# 91                                           Sí
# 93                                           Sí
#
#    ¿Consideras que la gente que te rodea goza de una buena salud mental?  \
# 0                                                  Sí
# 1                                                  Sí
# 2                                                  No
# 3                                Lo aparentan pero no
# 4                                Lo aparentan pero no
# ..                                                ...
# 88                               Lo aparentan pero no
# 89                                                 Sí
# 90                               Lo aparentan pero no
# 91                               Lo aparentan pero no
# 93                               Lo aparentan pero no
#
#                 Indica el por qué crees que no tienen  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Veo a mucha gente rota. Es una pauta general. ...
# 4                                                 NaN
# ..                                                ...
# 88    no concuerda lo que dicen con lo que demuestran
# 89                                                NaN
# 90                                       Inseguridad
# 91  Falta de autoestima por comparativa ante vidas...
# 93  Porque las RRSS (Tiktok e Instagram sobretodo)...
#
#    ¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?
# 0                                           Psicólogo
# 1                                           Psicólogo
# 2                        Me esperaría a que se pasara
# 3                        Me esperaría a que se pasara
# 4                                           Psicólogo
# ..                                                ...
# 88                                          Psicólogo
# 89                                          Psicólogo
# 90                                          Psicólogo
# 91                                          Psicólogo
# 93                                          Psicólogo
#
# [87 rows x 8 columns]

# %% [markdown]
# #### **Análisis de los datos de los resultados de la encuesta**
#
# - Tras descartar los participantes de las edades que se han mencionado anteriormente, nos ha quedado una muestra de 87 personas.

# %%
"En primer lugar, vamos a conocer el porcentaje de participantes que nunca se han comparado con alguien que siguen en RRSS."""

comparaciónRRSS_negativa = saludmental_RRSS['¿Alguna vez te has comparado con personas a las que sigues en RRSS?'] == 'No'
comparaciónRRSS_negativa = saludmental_RRSS[comparaciónRRSS_negativa]

"En segundo lugar, vamos a conocer el porcentaje de participantes que se han comparado con alguien que siguen en RRSS."""

comparaciónRRSS_positiva = saludmental_RRSS['¿Alguna vez te has comparado con personas a las que sigues en RRSS?'] != "No"
comparaciónRRSS_positiva = saludmental_RRSS[comparaciónRRSS_positiva]

"En tercer lugar, vamos a conocer el porcentaje de participantes que afirman haber sentido complejo de inferioridad al compararse en RRSS."

inferioridad = comparaciónRRSS_positiva['¿Te has sentido inferior al hacerlo?'] != "No"
inferioridad = comparaciónRRSS_positiva[inferioridad]

"En cuarto lugar, vamos a conocer el porcentaje de participantes que afirman que las RRSS influencian en la toma de sus decisiones."

influencia = saludmental_RRSS['¿Crees que influye en nuestra toma de decisiones los que vemos en RRSS?'] != 'No'
influencia = saludmental_RRSS[influencia]

"En quinto lugar, vamos a conocer el porcentaje de participantes que son incapaces de estar sin RRSS."

incapazRRSS = saludmental_RRSS['¿Has estado algun periodo de tiempo sin RRSS para desconectar?'] == 'Soy incapaz'
incapazRRSS = saludmental_RRSS[incapazRRSS]

"En sexto lugar, vamos a conocer el porcentaje de participantes que an logrado estar una semana sin RRSS."

semanasinRRSS = saludmental_RRSS['¿Has estado algun periodo de tiempo sin RRSS para desconectar?'] == 'Una semana'
semanasinRRSS = saludmental_RRSS[semanasinRRSS]

"En séptimo lugar, vamos a conocer el porcentaje de participantes que han logrado estar más de un mes sin RRSS."

masdeunmessinRRSS = saludmental_RRSS['¿Has estado algun periodo de tiempo sin RRSS para desconectar?'] == 'Más de un mes'
masdeunmessinRRSS = saludmental_RRSS[masdeunmessinRRSS]

"En octavo lugar, vamos a conocer el porcentaje de participantes que consideran que estar sin RRSS resulta beneficioso para su salud mental."

beneficiosoRRSS = saludmental_RRSS['En caso afirmativo, ¿crees que te benefició?'] != 'No'
beneficiosoRRSS = saludmental_RRSS[beneficiosoRRSS]

"En noveno lugar, vamos a conocer el porcentaje de participantes que consideran que las personas que le rodean no tienen buena salud mental."

saludmentalmala = saludmental_RRSS['¿Consideras que la gente que te rodea goza de una buena salud mental?'] != 'Sí'
saludmentalmala = saludmental_RRSS[saludmentalmala]

"En décimo lugar, vamos a conocer el porcentaje de participantes que no estarían dispuestos a recibir ayuda en caso de tener algún síntoma de depresión."

recibirayuda = saludmental_RRSS['¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?'] == 'Me esperaría a que se pasara'
recibirayuda = saludmental_RRSS[recibirayuda]

"En onceavo lugar, vamos a conocer el porcentaje de participantes que estarían dispuestos a acudir a un psicólogo en caso de tener algún síntoma de depresión."

recibirayudapsicologo = saludmental_RRSS['¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?'] == 'Psicólogo'
recibirayudapsicologo = saludmental_RRSS[recibirayudapsicologo]

"En doceavo lugar, vamos a conocer el porcentaje de participantes que estarían dispuestos a acudir a un psiquiatra en caso de tener algún síntoma de depresión."

recibirayudapsiquiatra = saludmental_RRSS['¿Estarías dispuesto de acudir a un especialista si tuvieras algún síntoma de depresión?'] == 'Psiquiatra'
recibirayudapsiquiatra = saludmental_RRSS[recibirayudapsiquiatra]

# %% [markdown]
# #### **Comprobaciones realizadas y conclusiones**

# %% [markdown]
# 1) Primer paso

# %%
"De los 87 participantes, únicamente el 20,7% nunca se han comparado con nadie en RRSS."

comparaciónRRSS_negativa.shape

cn = 18/87
cn*100
# Out:
# 20.689655172413794

# %% [markdown]
# 2) Segundo paso

# %%
"De los 87 participantes, el 79,3% se han comparado con alguien en RRSS en alguna ocasión."

comparaciónRRSS_positiva.shape

cp = 69/87
cp*100
# Out:
# 79.3103448275862

# %% [markdown]
# 3) Tercer paso

# %%
"De los 69 participantes que se han comparado con alguien en RRSS en alguna ocasión, el 89,85% afirman que han sentido complejo de inferioridad en alguna ocasión."

inferioridad.shape

cpi = 62/69
cpi*100
# Out:
# 89.85507246376811

# %% [markdown]
# 4) Cuarto paso

# %%
"De los 87 participantes, el 89,65% afirma que las RRSS influencian en la toma de sus decisiones."

influencia.shape

irrss = 78/87
irrss*100
# Out:
# 89.65517241379311

# %% [markdown]
# 5) Quinto paso

# %%
"De los 71 participantes que han respondido a esta cuestión, el 26,76% afirma que han sido incapaces de estar sin RRSS durante un tiempo."

incapazRRSS.shape

incrrss = 19/71
incrrss*100
# Out:
# 26.76056338028169

# %% [markdown]
# 6) Sexto paso

# %%
"De los 71 participantes que han respondido a esta cuestión, el 46,48% afirma que han sido capaces de estar sin RRSS durante una semana."

semanasinRRSS.shape

ssRRSS = 33/71
ssRRSS*100
# Out:
# 46.478873239436616

# %% [markdown]
# 7. Séptimo paso

# %%
"De los 71 participantes que han respondido a esta cuestión, el 26,76% afirma que han sido capaces de estar sin RRSS más de un mes."

masdeunmessinRRSS.shape

msRRSS = 19/71
msRRSS*100
# Out:
# 26.76056338028169

# %% [markdown]
# 8) Octavo paso

# %%
"De los 87 participantes, el 96,55% afirma que estar sin RRSS resulta beneficioso para su salud mental."

beneficiosoRRSS.shape

bsRRSS = 84/87
bsRRSS*100
# Out:
# 96.55172413793103

# %% [markdown]
# 9) Noveno paso

# %%
"De los 83 participantes que han respondido a esta cuestión, el 61,45% considera que las personas que le rodean no tienen una buena salud mental."

saludmentalmala.shape

smRRSS = 51/83
smRRSS*100
# Out:
# 61.44578313253012

# %% [markdown]
# 10) Décimo paso

# %%
"De los 87 participantes, el 4,6% no aceptaría obtener ayuda en caso de tener algún síntoma de depresión."

recibirayuda.shape

ra = 4/87
ra*100
# Out:
# 4.597701149425287

# %% [markdown]
# 11) Onceavo paso

# %%
"De los 87 participantes, el 83,9% estaría dispuesto a acudir a un psicólogo en caso de tener algún síntoma de depresión."

recibirayudapsicologo.shape

raps = 73/87
raps*100
# Out:
# 83.9080459770115

# %% [markdown]
# 12. Duodécimo paso

# %%
"De los 87 participantes, el 11,5% estaría dispuesto a acudir a un psiquiatra en caso de tener algún síntoma de depresión."

recibirayudapsiquiatra.shape

rapq = 10/87
rapq*100
# Out:
# 11.494252873563218
